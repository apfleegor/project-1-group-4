# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
happiness_df = pd.read_csv('Gallup2018.csv')

# %%
happiness_df
# Out:
#              State  2018 sample size  Well-Being Index  Well-Being Index Rank  \
# 0           Hawaii               502              64.6                      1
# 1          Wyoming               219              64.2                      2
# 2           Alaska               212              63.9                      3
# 3          Montana               488              63.5                      4
# 4             Utah              1214              63.4                      5
# 5         Colorado              2316              63.4                      6
# 6          Vermont               283              63.3                      7
# 7         Delaware               386              62.9                      8
# 8     South Dakota               402              62.7                      9
# 9     North Dakota               340              62.7                     10
# 10   New Hampshire               606              62.7                     11
# ...
