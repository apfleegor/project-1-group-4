# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
happiness_df = pd.read_csv('Resources/Gallup2018.csv')
nationalparks_df = pd.read_csv('Resources/StatesRanked_NationalParkCoverage.csv')

# %%
happiness_df.head()
# Out:
#      State  2018 sample size  Well-Being Index  Well-Being Index Rank  Career  \
# 0   Hawaii               502              64.6                      1       1
# 1  Wyoming               219              64.2                      2       3
# 2   Alaska               212              63.9                      3       5
# 3  Montana               488              63.5                      4       4
# 4     Utah              1214              63.4                      5       2
#
#    Social  Financial  Community  Physical
# 0       1          1          4         4
# 1      18          6          1         3
# 2       8          2         23         1
# 3      19         17          2         7
# 4       4         13          9        14

# %%
nationalparks_df.head()
# Out:
#        STATE   Rank State Size (acres)  Number of State Parks  \
# 0     Alabama    46         33,432,000                     22
# 1      Alaska     2        393,747,000                    119
# 2     Arizona    12         72,964,000                     36
# 3  California     3        101,676,000                    270
# 4    Colorado    25         66,624,000                     43
#
#   # of State Parks (acres)  State Coverage of State Parks  \
# 0                   48,000                           0.14
# 1                3,300,000                           0.84
# 2                   60,000                           0.08
# 3                1,300,000                           1.28
# 4                  220,000                           0.33
#
#    Number of National Parks State Coverage of National Parks (acres)  \
# 0                         0                                        0
# 1                         8                               32,526,051
# 2                         3                                1,514,753
# 3                         9                                6,313,164
# 4                         4                                  456,414
#
#    State Coverage of National Parks Total Acreage  Percent Covered   \
# 0                              0.00        48,000              0.14
# 1                              8.26    35,826,051              9.10
# 2                              2.08     1,574,753              2.16
# 3                              6.21     7,613,164              7.49
# 4                              0.69       676,414              1.02
#
#    Unnamed: 11  Unnamed: 12
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
